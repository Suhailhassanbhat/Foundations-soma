# %% [markdown]
# # Dark Sky API (Weather)
#
# Answer the following questions using the [Dark Sky API](https://darksky.net/dev/). I've added three cells for each question but you're free to use more or less! Hold `Shift` and hit `Enter` to run a cell, and use the `+` on the top left to add a new cell to a notebook.
#
# If you spend some time reading the documentation your life will probably be a little bit easier!
#
# ## 0) Import any libraries you might need
#
# - *Tip: We're going to be downloading things from the internet, so we probably need `requests`.*

# %%
import requests

# %% [markdown]
# ## 1) Make a request from the Dark Sky API for where you were born (or lived, or want to visit!).
#
# - *Tip: The URL we used in class was for a place near San Francisco. What was the format of the endpoint that made this happen?*
# - *Tip: Save the URL as a separate variable, and be sure to not have `[` and `]` inside.*
# - *Tip: How is north vs. south and east vs. west latitude/longitude represented? Is it the normal North/South/East/West?*
# - *Tip: You know it's JSON, but Python doesn't! Make sure you aren't trying to deal with plain text.*
# - *Tip: Once you've imported the JSON into a variable, check the timezone's name to make sure it seems like it got the right part of the world!*

# %%
from dotenv import load_dotenv
load_dotenv('/Users/suhailbhat/Desktop/foundations/Foundations-soma/env')
import os
DARKSKY_API_KEY = os.getenv('DARKSKY_API_KEY')

# %%
response = requests.get(f'https://api.darksky.net/forecast/{DARKSKY_API_KEY}/33.7,76.5')
data = response.json()

# %% [markdown]
# ## 2) What's the current wind speed? How much warmer does it feel than it actually is?
#
# - *Tip: You can do this by browsing through the dictionaries, but it might be easier to read the documentation*
# - *Tip: For the second half: it **is** one temperature, and it **feels** a different temperature. Calculate the difference.*

# %%
print(data['currently']['windSpeed'])
# Out:
# 3.59

# %%
print(data['currently']['apparentTemperature'])
# Out:
# 29.75

# %% [markdown]
# ## 3) Today's forecast is the FIRST daily forecast. For the place you decided on above, how much of the moon is currently visible?
#
# - *Tip: This does **not** use the `currently` key.*
# - *Tip: It might be helpful to save the forecast into its own variable*

# %%
print(data['daily'].keys())
# Out:
# dict_keys(['summary', 'icon', 'data'])

# %%
print(data['daily']['data'][0]['moonPhase'], "to a first quarter moon")
# Out:
# 0.76 to a first quarter moon

# %% [markdown]
# ## 4) What's the difference between the high and low temperatures for today?

# %%
print("Difference between the high and low temperatures for today was", round(data['daily']['data'][0]['temperatureHigh']- data['daily']['data'][0]['temperatureLow'], 2))
# Out:
# Difference between the high and low temperatures for today was 15.42

# %% [markdown]
# ## 5) Go through the daily forecasts, printing out the next week's worth of predictions.
#
# I'd like to know the **high temperature** for each day, and whether it's **hot, warm, or cold** (based on what temperatures you think are hot, warm or cold).
#
# - *Tip: Is it returning F or C? You can change them by adding `?units=us` or `?units=si` onto the end of the URL.*
# - *Tip: You'll need to use an `if` statement to say whether it is hot, warm or cold.*

# %%
daily_data = data['daily']['data']
for temperature in daily_data:
    print(temperature['temperatureHigh'])
    if temperature['temperatureHigh']>40:
        print("it will be a hot")
    elif temperature['temperatureHigh'] < 35:
        print("it will be cold")
    else:
        print("it will be warm")
# Out:
# 39.01
# it will be warm
# 37.87
# it will be warm
# 38.51
# it will be warm
# 36.7
# it will be warm
# 38.07
# it will be warm
# 39.51
# it will be warm
# 40.11
# it will be a hot
# 41.14
# it will be a hot

# %% [markdown]
# # 6) What will be the hottest day in the next week? What is the high temperature on that day?
#
# It's okay if your result looks like `1453363200`. If you want to be extra-fancy, though, format it as a **real date** - the weird number is called a **UNIX timestamp**, which might help in googling.
#
# - *Tip: It's okay to skip this if it seems too difficult!*

# %%
for temperature in daily_data:
    print(temperature['temperatureHigh'], temperature['time'])
# Out:
# 39.01 1561401000
# 37.87 1561487400
# 38.51 1561573800
# 36.7 1561660200
# 38.07 1561746600
# 39.51 1561833000
# 40.11 1561919400
# 41.14 1562005800

# %%
temperatures_for_nextweek = [37.77, 37.74, 35.46, 31.59, 38.88, 40.91, 31.29, 38.81]
for temperature in daily_data:
    if temperature['temperatureHigh'] == 40.91:
        print(temperature['time'], "will be the hotest day in the next week", "with high temperature of", max(temperatures_for_nextweek), "F")

# %% [markdown]
# ## 7) What's the weather looking like for the next 24+ hours in Miami, Florida?
#
# I'd like to know the temperature for every hour, and if it's going to have cloud cover of more than 50% say "{temperature} and cloudy" instead of just the temperature.
#
#
# - *Tip: Be sure to remember how latitude and longitude are done with positive and negative numbers*
# - *Tip: How do you represent "50%" for cloud cover?*

# %%
response = requests.get('https://api.darksky.net/forecast/37e68ae8fad94bcf37e87015f2f7a1b9/25.7617, -80.1918')
miami_data = response.json()
miami_data['hourly']
# Out:
# {'summary': 'Humid throughout the day.',
#  'icon': 'clear-day',
#  'data': [{'time': 1561435200,
#    'summary': 'Humid',
#    'icon': 'clear-night',
#    'precipIntensity': 0,
#    'precipProbability': 0,
#    'temperature': 83.71,
#    'apparentTemperature': 91.69,
#    'dewPoint': 75.22,
#    'humidity': 0.76,
#    'pressure': 1017.83,
#    'windSpeed': 4.46,
#    'windGust': 4.46,
#    'windBearing': 169,
#    'cloudCover': 0,
#    'uvIndex': 0,
#    'visibility': 10,
#    'ozone': 296.9},
#   {'time': 1561438800,
#    'summary': 'Humid',
#    'icon': 'clear-night',
#    'precipIntensity': 0,
#    'precipProbability': 0,
#    'temperature': 83.29,
#    'apparentTemperature': 90.77,
#    'dewPoint': 74.92,
#    'humidity': 0.76,
#    'pressure': 1017.79,
#    'windSpeed': 4.13,
#    'windGust': 4.13,
#    'windBearing': 168,
#    'cloudCover': 0,
#    'uvIndex': 0,
#    'visibility': 10,
#    'ozone': 296.5},
#   {'time': 1561442400,
#    'summary': 'Humid',
#    'icon': 'clear-night',
#    'precipIntensity': 0,
#    'precipProbability': 0,
#    'temperature': 81.72,
#    'apparentTemperature': 87.52,
#    'dewPoint': 73.99,
#    'humidity': 0.77,
#    'pressure': 1016.97,
#    'windSpeed': 3.97,
#    'windGust': 3.97,
#    'windBearing': 202,
#    'cloudCover': 0.03,
#    'uvIndex': 0,
#    'visibility': 10,
#    'ozone': 296.3},
#   {'time': 1561446000,
#    'summary': 'Humid and Partly Cloudy',
#    'icon': 'partly-cloudy-night',
#    'precipIntensity': 0.001,
#    'precipProbability': 0.02,
#    'precipType': 'rain',
#    'temperature': 80.44,
#    'apparentTemperature': 85.07,
#    'dewPoint': 73.44,
#    'humidity': 0.79,
#    'pressure': 1016.15,
#    'windSpeed': 4.05,
#    'windGust': 5.93,
#    'windBearing': 214,
#    'cloudCover': 0.13,
#    'uvIndex': 0,
#    'visibility': 10,
#    'ozone': 296.3},
#   {'time': 1561449600,
#    'summary': 'Humid and Partly Cloudy',
#    'icon': 'partly-cloudy-night',
#    'precipIntensity': 0.001,
#    'precipProbability': 0.02,
#    'precipType': 'rain',
#    'temperature': 79.42,
#    'apparentTemperature': 83.25,
#    'dewPoint': 73.51,
#    'humidity': 0.82,
#    'pressure': 1015.71,
#    'windSpeed': 4.16,
#    'windGust': 5.85,
#    'windBearing': 212,
#    'cloudCover': 0.18,
#    'uvIndex': 0,
#    'visibility': 10,
#    'ozone': 296.3},
#   {'time': 1561453200,
#    'summary': 'Humid and Partly Cloudy',
#    'icon': 'partly-cloudy-night',
#    'precipIntensity': 0.001,
#    'precipProbability': 0.02,
#    'precipType': 'rain',
#    'temperature': 79.11,
#    'apparentTemperature': 82.7,
#    'dewPoint': 73.63,
#    'humidity': 0.83,
#    'pressure': 1015.43,
#    'windSpeed': 4.4,
#    'windGust': 6.11,
#    'windBearing': 205,
#    'cloudCover': 0.18,
#    'uvIndex': 0,
#    'visibility': 10,
#    'ozone': 296.6},
#   {'time': 1561456800,
#    'summary': 'Humid and Partly Cloudy',
#    'icon': 'partly-cloudy-night',
#    'precipIntensity': 0.001,
#    'precipProbability': 0.02,
#    'precipType': 'rain',
#    'temperature': 79.46,
#    'apparentTemperature': 83.44,
#    'dewPoint': 73.92,
#    'humidity': 0.83,
#    'pressure': 1015.7,
#    'windSpeed': 4.52,
#    'windGust': 6.51,
#    'windBearing': 194,
#    'cloudCover': 0.13,
#    'uvIndex': 0,
#    'visibility': 10,
#    'ozone': 297.1},
#   {'time': 1561460400,
#    'summary': 'Humid',
#    'icon': 'clear-day',
#    'precipIntensity': 0,
#    'precipProbability': 0,
#    'temperature': 80.22,
#    'apparentTemperature': 85.04,
#    'dewPoint': 74.34,
#    'humidity': 0.82,
#    'pressure': 1016.21,
#    'windSpeed': 4.38,
#    'windGust': 6.48,
#    'windBearing': 218,
#    'cloudCover': 0.11,
#    'uvIndex': 0,
#    'visibility': 10,
#    'ozone': 297.9},
#   {'time': 1561464000,
#    'summary': 'Humid',
#    'icon': 'clear-day',
#    'precipIntensity': 0,
#    'precipProbability': 0,
#    'temperature': 81.96,
#    'apparentTemperature': 88.31,
#    'dewPoint': 74.59,
#    'humidity': 0.78,
#    'pressure': 1016.87,
#    'windSpeed': 4.19,
#    'windGust': 6.24,
#    'windBearing': 229,
#    'cloudCover': 0.08,
#    'uvIndex': 1,
#    'visibility': 10,
#    'ozone': 298.3},
#   {'time': 1561467600,
#    'summary': 'Humid',
#    'icon': 'clear-day',
#    'precipIntensity': 0.002,
#    'precipProbability': 0.02,
#    'precipType': 'rain',
#    'temperature': 84.38,
#    'apparentTemperature': 91.74,
#    'dewPoint': 74.05,
#    'humidity': 0.71,
#    'pressure': 1017.41,
#    'windSpeed': 3.93,
#    'windGust': 5.57,
#    'windBearing': 234,
#    'cloudCover': 0.06,
#    'uvIndex': 2,
#    'visibility': 10,
#    'ozone': 298.1},
#   {'time': 1561471200,
#    'summary': 'Humid',
#    'icon': 'clear-day',
#    'precipIntensity': 0,
#    'precipProbability': 0,
#    'temperature': 86.9,
#    'apparentTemperature': 94.75,
#    'dewPoint': 73.48,
#    'humidity': 0.64,
#    'pressure': 1017.76,
#    'windSpeed': 3.3,
#    'windGust': 4.43,
#    'windBearing': 217,
#    'cloudCover': 0.03,
#    'uvIndex': 5,
#    'visibility': 10,
#    'ozone': 297.6},
#   {'time': 1561474800,
#    'summary': 'Humid',
#    'icon': 'clear-day',
#    'precipIntensity': 0.001,
#    'precipProbability': 0.02,
#    'precipType': 'rain',
#    'temperature': 88.82,
#    'apparentTemperature': 96.98,
#    'dewPoint': 73.18,
#    'humidity': 0.6,
#    'pressure': 1017.92,
#    'windSpeed': 3.4,
#    'windGust': 4.48,
#    'windBearing': 215,
#    'cloudCover': 0.01,
#    'uvIndex': 8,
#    'visibility': 10,
#    'ozone': 297.2},
#   {'time': 1561478400,
#    'summary': 'Humid',
#    'icon': 'clear-day',
#    'precipIntensity': 0.002,
#    'precipProbability': 0.02,
#    'precipType': 'rain',
#    'temperature': 90.05,
#    'apparentTemperature': 98.36,
#    'dewPoint': 72.98,
#    'humidity': 0.57,
#    'pressure': 1017.93,
#    'windSpeed': 3.86,
#    'windGust': 5.68,
#    'windBearing': 197,
#    'cloudCover': 0.03,
#    'uvIndex': 10,
#    'visibility': 10,
#    'ozone': 297.4},
#   {'time': 1561482000,
#    'summary': 'Humid',
#    'icon': 'clear-day',
#    'precipIntensity': 0.002,
#    'precipProbability': 0.01,
#    'precipType': 'rain',
#    'temperature': 91.26,
#    'apparentTemperature': 99.78,
#    'dewPoint': 72.87,
#    'humidity': 0.55,
#    'pressure': 1017.7,
#    'windSpeed': 5.14,
#    'windGust': 7.11,
#    'windBearing': 152,
#    'cloudCover': 0.04,
#    'uvIndex': 11,
#    'visibility': 10,
#    'ozone': 297.9},
#   {'time': 1561485600,
#    'summary': 'Humid',
#    'icon': 'clear-day',
#    'precipIntensity': 0.005,
#    'precipProbability': 0.02,
#    'precipType': 'rain',
#    'temperature': 91.68,
#    'apparentTemperature': 99.48,
#    'dewPoint': 72.07,
#    'humidity': 0.53,
#    'pressure': 1017.46,
#    'windSpeed': 6.28,
#    'windGust': 7.41,
#    'windBearing': 131,
#    'cloudCover': 0,
#    'uvIndex': 11,
#    'visibility': 10,
#    'ozone': 298.2},
#   {'time': 1561489200,
#    'summary': 'Humid',
#    'icon': 'clear-day',
#    'precipIntensity': 0.005,
#    'precipProbability': 0.02,
#    'precipType': 'rain',
#    'temperature': 91.36,
#    'apparentTemperature': 99.19,
#    'dewPoint': 72.19,
#    'humidity': 0.54,
#    'pressure': 1017.08,
#    'windSpeed': 8,
#    'windGust': 8.76,
#    'windBearing': 125,
#    'cloudCover': 0.06,
#    'uvIndex': 9,
#    'visibility': 10,
#    'ozone': 298.1},
#   {'time': 1561492800,
#    'summary': 'Humid',
#    'icon': 'clear-day',
#    'precipIntensity': 0.003,
#    'precipProbability': 0.02,
#    'precipType': 'rain',
#    'temperature': 90.22,
#    'apparentTemperature': 97.95,
#    'dewPoint': 72.37,
#    'humidity': 0.56,
#    'pressure': 1016.79,
#    'windSpeed': 9.38,
#    'windGust': 10.2,
#    'windBearing': 126,
#    'cloudCover': 0.02,
#    'uvIndex': 7,
#    'visibility': 10,
#    'ozone': 297.7},
#   {'time': 1561496400,
#    'summary': 'Humid',
#    'icon': 'clear-day',
#    'precipIntensity': 0.002,
#    'precipProbability': 0.02,
#    'precipType': 'rain',
#    'temperature': 89.19,
#    'apparentTemperature': 96.85,
#    'dewPoint': 72.58,
#    'humidity': 0.58,
#    'pressure': 1016.47,
#    'windSpeed': 9.31,
#    'windGust': 11,
#    'windBearing': 130,
#    'cloudCover': 0.03,
#    'uvIndex': 4,
#    'visibility': 10,
#    'ozone': 297.3},
#   {'time': 1561500000,
#    'summary': 'Humid',
#    'icon': 'clear-day',
#    'precipIntensity': 0.001,
#    'precipProbability': 0.02,
#    'precipType': 'rain',
#    'temperature': 88.07,
#    'apparentTemperature': 95.67,
#    'dewPoint': 72.83,
#    'humidity': 0.61,
#    'pressure': 1016.5,
#    'windSpeed': 9.12,
#    'windGust': 10.81,
#    'windBearing': 137,
#    'cloudCover': 0.05,
#    'uvIndex': 2,
#    'visibility': 10,
#    'ozone': 296.6},
#   {'time': 1561503600,
#    'summary': 'Humid',
#    'icon': 'clear-day',
#    'precipIntensity': 0.001,
#    'precipProbability': 0.02,
#    'precipType': 'rain',
#    'temperature': 86.68,
#    'apparentTemperature': 94.11,
#    'dewPoint': 73.11,
#    'humidity': 0.64,
#    'pressure': 1016.6,
#    'windSpeed': 8.29,
#    'windGust': 10.06,
#    'windBearing': 148,
#    'cloudCover': 0.08,
#    'uvIndex': 0,
#    'visibility': 10,
#    'ozone': 295.8},
#   {'time': 1561507200,
#    'summary': 'Humid and Partly Cloudy',
#    'icon': 'partly-cloudy-day',
#    'precipIntensity': 0.001,
#    'precipProbability': 0.02,
#    'precipType': 'rain',
#    'temperature': 85.31,
#    'apparentTemperature': 92.51,
#    'dewPoint': 73.39,
#    'humidity': 0.68,
#    'pressure': 1016.87,
#    'windSpeed': 7.34,
#    'windGust': 9.16,
#    'windBearing': 158,
#    'cloudCover': 0.13,
#    'uvIndex': 0,
#    'visibility': 10,
#    'ozone': 295.3},
#   {'time': 1561510800,
#    'summary': 'Humid and Partly Cloudy',
#    'icon': 'partly-cloudy-night',
#    'precipIntensity': 0.001,
#    'precipProbability': 0.02,
#    'precipType': 'rain',
#    'temperature': 83.99,
#    'apparentTemperature': 90.85,
#    'dewPoint': 73.66,
#    'humidity': 0.71,
#    'pressure': 1017.23,
#    'windSpeed': 6.54,
#    'windGust': 7.99,
#    'windBearing': 166,
#    'cloudCover': 0.16,
#    'uvIndex': 0,
#    'visibility': 10,
#    'ozone': 295.5},
#   {'time': 1561514400,
#    'summary': 'Humid and Partly Cloudy',
#    'icon': 'partly-cloudy-night',
#    'precipIntensity': 0.001,
#    'precipProbability': 0.02,
#    'precipType': 'rain',
#    'temperature': 82.88,
#    'apparentTemperature': 89.33,
#    'dewPoint': 73.88,
#    'humidity': 0.74,
#    'pressure': 1017.62,
#    'windSpeed': 5.9,
#    'windGust': 6.69,
#    'windBearing': 170,
#    'cloudCover': 0.15,
#    'uvIndex': 0,
#    'visibility': 10,
#    'ozone': 296.1},
#   {'time': 1561518000,
#    'summary': 'Humid',
#    'icon': 'clear-night',
#    'precipIntensity': 0.001,
#    'precipProbability': 0.02,
#    'precipType': 'rain',
#    'temperature': 81.98,
#    'apparentTemperature': 88.03,
#    'dewPoint': 74.1,
#    'humidity': 0.77,
#    'pressure': 1017.95,
#    'windSpeed': 5.42,
#    'windGust': 5.95,
#    'windBearing': 176,
#    'cloudCover': 0.12,
#    'uvIndex': 0,
#    'visibility': 10,
#    'ozone': 296.2},
#   {'time': 1561521600,
#    'summary': 'Humid',
#    'icon': 'clear-night',
#    'precipIntensity': 0.001,
#    'precipProbability': 0.02,
#    'precipType': 'rain',
#    'temperature': 81.38,
#    'apparentTemperature': 87.18,
#    'dewPoint': 74.39,
#    'humidity': 0.79,
#    'pressure': 1017.95,
#    'windSpeed': 5.3,
#    'windGust': 6.33,
#    'windBearing': 180,
#    'cloudCover': 0.11,
#    'uvIndex': 0,
#    'visibility': 10,
#    'ozone': 295.9},
#   {'time': 1561525200,
#    'summary': 'Humid',
#    'icon': 'clear-night',
#    'precipIntensity': 0,
#    'precipProbability': 0,
#    'temperature': 81.14,
#    'apparentTemperature': 86.94,
#    'dewPoint': 74.73,
#    'humidity': 0.81,
#    'pressure': 1017.73,
#    'windSpeed': 5.36,
#    'windGust': 7.24,
#    'windBearing': 183,
#    'cloudCover': 0.05,
#    'uvIndex': 0,
#    'visibility': 10,
#    'ozone': 295.3},
#   {'time': 1561528800,
#    'summary': 'Humid',
#    'icon': 'clear-night',
#    'precipIntensity': 0,
#    'precipProbability': 0,
#    'temperature': 80.95,
#    'apparentTemperature': 86.71,
#    'dewPoint': 74.96,
#    'humidity': 0.82,
#    'pressure': 1017.46,
#    'windSpeed': 5.26,
#    'windGust': 7.76,
#    'windBearing': 188,
#    'cloudCover': 0.04,
#    'uvIndex': 0,
#    'visibility': 10,
#    'ozone': 294.8},
#   {'time': 1561532400,
#    'summary': 'Humid',
#    'icon': 'clear-night',
#    'precipIntensity': 0,
#    'precipProbability': 0,
#    'temperature': 80.52,
#    'apparentTemperature': 85.94,
#    'dewPoint': 75.04,
#    'humidity': 0.83,
#    'pressure': 1017.17,
#    'windSpeed': 4.96,
#    'windGust': 7.37,
#    'windBearing': 193,
#    'cloudCover': 0.03,
#    'uvIndex': 0,
#    'visibility': 10,
#    'ozone': 294.8},
#   {'time': 1561536000,
#    'summary': 'Humid',
#    'icon': 'clear-night',
#    'precipIntensity': 0,
#    'precipProbability': 0,
#    'temperature': 79.87,
#    'apparentTemperature': 84.64,
#    'dewPoint': 75.03,
#    'humidity': 0.85,
#    'pressure': 1016.92,
#    'windSpeed': 4.53,
#    'windGust': 6.54,
#    'windBearing': 199,
#    'cloudCover': 0.03,
#    'uvIndex': 0,
#    'visibility': 10,
#    'ozone': 295},
#   {'time': 1561539600,
#    'summary': 'Humid',
#    'icon': 'clear-night',
#    'precipIntensity': 0,
#    'precipProbability': 0,
#    'temperature': 79.37,
#    'apparentTemperature': 83.59,
#    'dewPoint': 75.01,
#    'humidity': 0.87,
#    'pressure': 1016.84,
#    'windSpeed': 4.19,
#    'windGust': 5.95,
#    'windBearing': 209,
#    'cloudCover': 0.03,
#    'uvIndex': 0,
#    'visibility': 10,
#    'ozone': 295.4},
#   {'time': 1561543200,
#    'summary': 'Humid',
#    'icon': 'clear-night',
#    'precipIntensity': 0,
#    'precipProbability': 0,
#    'temperature': 79.23,
#    'apparentTemperature': 83.3,
#    'dewPoint': 75.02,
#    'humidity': 0.87,
#    'pressure': 1017.15,
#    'windSpeed': 3.95,
#    'windGust': 5.93,
#    'windBearing': 222,
#    'cloudCover': 0.05,
#    'uvIndex': 0,
#    'visibility': 10,
#    'ozone': 296.3},
#   {'time': 1561546800,
#    'summary': 'Humid',
#    'icon': 'clear-day',
#    'precipIntensity': 0,
#    'precipProbability': 0,
#    'temperature': 79.71,
#    'apparentTemperature': 84.28,
#    'dewPoint': 74.95,
#    'humidity': 0.85,
#    'pressure': 1017.69,
#    'windSpeed': 3.91,
#    'windGust': 6.15,
#    'windBearing': 238,
#    'cloudCover': 0.06,
#    'uvIndex': 0,
#    'visibility': 10,
#    'ozone': 297.5},
#   {'time': 1561550400,
#    'summary': 'Humid',
#    'icon': 'clear-day',
#    'precipIntensity': 0,
#    'precipProbability': 0,
#    'temperature': 81.16,
#    'apparentTemperature': 86.94,
#    'dewPoint': 74.66,
#    'humidity': 0.81,
#    'pressure': 1018.18,
#    'windSpeed': 4.08,
#    'windGust': 6.21,
#    'windBearing': 237,
#    'cloudCover': 0.08,
#    'uvIndex': 1,
#    'visibility': 10,
#    'ozone': 298.2},
#   {'time': 1561554000,
#    'summary': 'Humid and Partly Cloudy',
#    'icon': 'partly-cloudy-day',
#    'precipIntensity': 0,
#    'precipProbability': 0,
#    'temperature': 83.6,
#    'apparentTemperature': 90.42,
#    'dewPoint': 73.87,
#    'humidity': 0.73,
#    'pressure': 1018.52,
#    'windSpeed': 4.05,
#    'windGust': 5.88,
#    'windBearing': 214,
#    'cloudCover': 0.14,
#    'uvIndex': 2,
#    'visibility': 10,
#    'ozone': 298.1},
#   {'time': 1561557600,
#    'summary': 'Humid and Partly Cloudy',
#    'icon': 'partly-cloudy-day',
#    'precipIntensity': 0,
#    'precipProbability': 0,
#    'temperature': 86.32,
#    'apparentTemperature': 93.35,
#    'dewPoint': 72.8,
#    'humidity': 0.64,
#    'pressure': 1018.61,
#    'windSpeed': 3.69,
#    'windGust': 5.43,
#    'windBearing': 176,
#    'cloudCover': 0.18,
#    'uvIndex': 5,
#    'visibility': 10,
#    'ozone': 297.6},
#   {'time': 1561561200,
#    'summary': 'Humid and Partly Cloudy',
#    'icon': 'partly-cloudy-day',
#    'precipIntensity': 0,
#    'precipProbability': 0,
#    'temperature': 88.25,
#    'apparentTemperature': 95.12,
#    'dewPoint': 72.01,
#    'humidity': 0.59,
#    'pressure': 1018.68,
#    'windSpeed': 3.87,
#    'windGust': 5.27,
#    'windBearing': 137,
#    'cloudCover': 0.21,
#    'uvIndex': 7,
#    'visibility': 10,
#    'ozone': 297.2},
#   {'time': 1561564800,
#    'summary': 'Partly Cloudy',
#    'icon': 'partly-cloudy-day',
#    'precipIntensity': 0.001,
#    'precipProbability': 0.02,
#    'precipType': 'rain',
#    'temperature': 89.56,
#    'apparentTemperature': 96.5,
#    'dewPoint': 71.73,
#    'humidity': 0.56,
#    'pressure': 1018.47,
#    'windSpeed': 5.16,
#    'windGust': 5.65,
#    'windBearing': 123,
#    'cloudCover': 0.25,
#    'uvIndex': 9,
#    'visibility': 10,
#    'ozone': 297.1},
#   {'time': 1561568400,
#    'summary': 'Partly Cloudy',
#    'icon': 'partly-cloudy-day',
#    'precipIntensity': 0.004,
#    'precipProbability': 0.02,
#    'precipType': 'rain',
#    'temperature': 90.66,
#    'apparentTemperature': 97.89,
#    'dewPoint': 71.75,
#    'humidity': 0.54,
#    'pressure': 1018.22,
#    'windSpeed': 7.09,
#    'windGust': 7.44,
#    'windBearing': 117,
#    'cloudCover': 0.2,
#    'uvIndex': 10,
#    'visibility': 10,
#    'ozone': 297.2},
#   {'time': 1561572000,
#    'summary': 'Clear',
#    'icon': 'clear-day',
#    'precipIntensity': 0.006,
#    'precipProbability': 0.03,
#    'precipType': 'rain',
#    'temperature': 90.71,
#    'apparentTemperature': 97.99,
#    'dewPoint': 71.79,
#    'humidity': 0.54,
#    'pressure': 1017.82,
#    'windSpeed': 8.8,
#    'windGust': 9.05,
#    'windBearing': 114,
#    'cloudCover': 0.11,
#    'uvIndex': 11,
#    'visibility': 10,
#    'ozone': 297.1},
#   {'time': 1561575600,
#    'summary': 'Clear',
#    'icon': 'clear-day',
#    'precipIntensity': 0.004,
#    'precipProbability': 0.03,
#    'precipType': 'rain',
#    'temperature': 90.42,
#    'apparentTemperature': 97.67,
#    'dewPoint': 71.82,
#    'humidity': 0.55,
#    'pressure': 1017.31,
#    'windSpeed': 9.82,
#    'windGust': 10.12,
#    'windBearing': 111,
#    'cloudCover': 0.08,
#    'uvIndex': 9,
#    'visibility': 10,
#    'ozone': 296.8},
#   {'time': 1561579200,
#    'summary': 'Clear',
#    'icon': 'clear-day',
#    'precipIntensity': 0.002,
#    'precipProbability': 0.02,
#    'precipType': 'rain',
#    'temperature': 89.65,
#    'apparentTemperature': 96.78,
#    'dewPoint': 71.9,
#    'humidity': 0.56,
#    'pressure': 1016.78,
#    'windSpeed': 10.39,
#    'windGust': 10.82,
#    'windBearing': 110,
#    'cloudCover': 0.06,
#    'uvIndex': 7,
#    'visibility': 10,
#    'ozone': 296.4},
#   {'time': 1561582800,
#    'summary': 'Humid',
#    'icon': 'clear-day',
#    'precipIntensity': 0.001,
#    'precipProbability': 0.03,
#    'precipType': 'rain',
#    'temperature': 88.51,
#    'apparentTemperature': 95.44,
#    'dewPoint': 72,
#    'humidity': 0.58,
#    'pressure': 1016.42,
#    'windSpeed': 10.64,
#    'windGust': 11.65,
#    'windBearing': 109,
#    'cloudCover': 0.04,
#    'uvIndex': 4,
#    'visibility': 10,
#    'ozone': 296.3},
#   {'time': 1561586400,
#    'summary': 'Humid',
#    'icon': 'clear-day',
#    'precipIntensity': 0.001,
#    'precipProbability': 0.03,
#    'precipType': 'rain',
#    'temperature': 87.33,
#    'apparentTemperature': 94.14,
#    'dewPoint': 72.21,
#    'humidity': 0.61,
#    'pressure': 1016.37,
#    'windSpeed': 10.15,
#    'windGust': 10.96,
#    'windBearing': 114,
#    'cloudCover': 0.04,
#    'uvIndex': 2,
#    'visibility': 10,
#    'ozone': 296.4},
#   {'time': 1561590000,
#    'summary': 'Humid',
#    'icon': 'clear-day',
#    'precipIntensity': 0,
#    'precipProbability': 0,
#    'temperature': 85.87,
#    'apparentTemperature': 92.5,
#    'dewPoint': 72.5,
#    'humidity': 0.64,
#    'pressure': 1016.64,
#    'windSpeed': 9.1,
#    'windGust': 9.27,
#    'windBearing': 121,
#    'cloudCover': 0.04,
#    'uvIndex': 0,
#    'visibility': 10,
#    'ozone': 296.6},
#   {'time': 1561593600,
#    'summary': 'Humid',
#    'icon': 'clear-day',
#    'precipIntensity': 0,
#    'precipProbability': 0,
#    'temperature': 84.45,
#    'apparentTemperature': 90.77,
#    'dewPoint': 72.73,
#    'humidity': 0.68,
#    'pressure': 1016.99,
#    'windSpeed': 8.01,
#    'windGust': 8.02,
#    'windBearing': 122,
#    'cloudCover': 0.05,
#    'uvIndex': 0,
#    'visibility': 10,
#    'ozone': 296.9},
#   {'time': 1561597200,
#    'summary': 'Humid and Partly Cloudy',
#    'icon': 'partly-cloudy-night',
#    'precipIntensity': 0.001,
#    'precipProbability': 0.04,
#    'precipType': 'rain',
#    'temperature': 83.02,
#    'apparentTemperature': 88.84,
#    'dewPoint': 72.86,
#    'humidity': 0.72,
#    'pressure': 1017.4,
#    'windSpeed': 7.02,
#    'windGust': 7.04,
#    'windBearing': 110,
#    'cloudCover': 0.14,
#    'uvIndex': 0,
#    'visibility': 10,
#    'ozone': 297},
#   {'time': 1561600800,
#    'summary': 'Humid and Partly Cloudy',
#    'icon': 'partly-cloudy-night',
#    'precipIntensity': 0.002,
#    'precipProbability': 0.04,
#    'precipType': 'rain',
#    'temperature': 81.97,
#    'apparentTemperature': 87.31,
#    'dewPoint': 72.94,
#    'humidity': 0.74,
#    'pressure': 1017.88,
#    'windSpeed': 6.23,
#    'windGust': 6.24,
#    'windBearing': 94,
#    'cloudCover': 0.26,
#    'uvIndex': 0,
#    'visibility': 10,
#    'ozone': 296.9},
#   {'time': 1561604400,
#    'summary': 'Humid and Partly Cloudy',
#    'icon': 'partly-cloudy-night',
#    'precipIntensity': 0.002,
#    'precipProbability': 0.04,
#    'precipType': 'rain',
#    'temperature': 81.22,
#    'apparentTemperature': 86.19,
#    'dewPoint': 73.04,
#    'humidity': 0.76,
#    'pressure': 1018.13,
#    'windSpeed': 5.81,
#    'windGust': 5.82,
#    'windBearing': 103,
#    'cloudCover': 0.34,
#    'uvIndex': 0,
#    'visibility': 10,
#    'ozone': 297.1},
#   {'time': 1561608000,
#    'summary': 'Humid and Partly Cloudy',
#    'icon': 'partly-cloudy-night',
#    'precipIntensity': 0.001,
#    'precipProbability': 0.03,
#    'precipType': 'rain',
#    'temperature': 80.76,
#    'apparentTemperature': 85.56,
#    'dewPoint': 73.3,
#    'humidity': 0.78,
#    'pressure': 1018.02,
#    'windSpeed': 5.85,
#    'windGust': 5.88,
#    'windBearing': 95,
#    'cloudCover': 0.34,
#    'uvIndex': 0,
#    'visibility': 10,
#    'ozone': 297.7},
#   {'time': 1561611600,
#    'summary': 'Humid and Partly Cloudy',
#    'icon': 'partly-cloudy-night',
#    'precipIntensity': 0,
#    'precipProbability': 0,
#    'temperature': 80.46,
#    'apparentTemperature': 85.17,
#    'dewPoint': 73.61,
#    'humidity': 0.8,
#    'pressure': 1017.71,
#    'windSpeed': 6.12,
#    'windGust': 6.33,
#    'windBearing': 95,
#    'cloudCover': 0.32,
#    'uvIndex': 0,
#    'visibility': 10,
#    'ozone': 298.6}]}

# %%
miami_data_hourly = miami_data['hourly']
for data in miami_data_hourly['data']:
    print("During", data['time'], "hour", ",temperature will be", data['temperature'],"F", "and", round(data['cloudCover']*100, 1), "% of sky occluded by clouds")
# Out:
# During 1561435200 hour ,temperature will be 83.71 F and 0 % of sky occluded by clouds
# During 1561438800 hour ,temperature will be 83.29 F and 0 % of sky occluded by clouds
# During 1561442400 hour ,temperature will be 81.72 F and 3.0 % of sky occluded by clouds
# During 1561446000 hour ,temperature will be 80.44 F and 13.0 % of sky occluded by clouds
# During 1561449600 hour ,temperature will be 79.42 F and 18.0 % of sky occluded by clouds
# During 1561453200 hour ,temperature will be 79.11 F and 18.0 % of sky occluded by clouds
# During 1561456800 hour ,temperature will be 79.46 F and 13.0 % of sky occluded by clouds
# During 1561460400 hour ,temperature will be 80.22 F and 11.0 % of sky occluded by clouds
# During 1561464000 hour ,temperature will be 81.96 F and 8.0 % of sky occluded by clouds
# During 1561467600 hour ,temperature will be 84.38 F and 6.0 % of sky occluded by clouds
# During 1561471200 hour ,temperature will be 86.9 F and 3.0 % of sky occluded by clouds
# During 1561474800 hour ,temperature will be 88.82 F and 1.0 % of sky occluded by clouds
# During 1561478400 hour ,temperature will be 90.05 F and 3.0 % of sky occluded by clouds
# During 1561482000 hour ,temperature will be 91.26 F and 4.0 % of sky occluded by clouds
# During 1561485600 hour ,temperature will be 91.68 F and 0 % of sky occluded by clouds
# During 1561489200 hour ,temperature will be 91.36 F and 6.0 % of sky occluded by clouds
# During 1561492800 hour ,temperature will be 90.22 F and 2.0 % of sky occluded by clouds
# During 1561496400 hour ,temperature will be 89.19 F and 3.0 % of sky occluded by clouds
# During 1561500000 hour ,temperature will be 88.07 F and 5.0 % of sky occluded by clouds
# During 1561503600 hour ,temperature will be 86.68 F and 8.0 % of sky occluded by clouds
# During 1561507200 hour ,temperature will be 85.31 F and 13.0 % of sky occluded by clouds
# During 1561510800 hour ,temperature will be 83.99 F and 16.0 % of sky occluded by clouds
# During 1561514400 hour ,temperature will be 82.88 F and 15.0 % of sky occluded by clouds
# During 1561518000 hour ,temperature will be 81.98 F and 12.0 % of sky occluded by clouds
# During 1561521600 hour ,temperature will be 81.38 F and 11.0 % of sky occluded by clouds
# During 1561525200 hour ,temperature will be 81.14 F and 5.0 % of sky occluded by clouds
# During 1561528800 hour ,temperature will be 80.95 F and 4.0 % of sky occluded by clouds
# During 1561532400 hour ,temperature will be 80.52 F and 3.0 % of sky occluded by clouds
# During 1561536000 hour ,temperature will be 79.87 F and 3.0 % of sky occluded by clouds
# During 1561539600 hour ,temperature will be 79.37 F and 3.0 % of sky occluded by clouds
# During 1561543200 hour ,temperature will be 79.23 F and 5.0 % of sky occluded by clouds
# During 1561546800 hour ,temperature will be 79.71 F and 6.0 % of sky occluded by clouds
# During 1561550400 hour ,temperature will be 81.16 F and 8.0 % of sky occluded by clouds
# During 1561554000 hour ,temperature will be 83.6 F and 14.0 % of sky occluded by clouds
# During 1561557600 hour ,temperature will be 86.32 F and 18.0 % of sky occluded by clouds
# During 1561561200 hour ,temperature will be 88.25 F and 21.0 % of sky occluded by clouds
# During 1561564800 hour ,temperature will be 89.56 F and 25.0 % of sky occluded by clouds
# During 1561568400 hour ,temperature will be 90.66 F and 20.0 % of sky occluded by clouds
# During 1561572000 hour ,temperature will be 90.71 F and 11.0 % of sky occluded by clouds
# During 1561575600 hour ,temperature will be 90.42 F and 8.0 % of sky occluded by clouds
# During 1561579200 hour ,temperature will be 89.65 F and 6.0 % of sky occluded by clouds
# During 1561582800 hour ,temperature will be 88.51 F and 4.0 % of sky occluded by clouds
# During 1561586400 hour ,temperature will be 87.33 F and 4.0 % of sky occluded by clouds
# During 1561590000 hour ,temperature will be 85.87 F and 4.0 % of sky occluded by clouds
# During 1561593600 hour ,temperature will be 84.45 F and 5.0 % of sky occluded by clouds
# During 1561597200 hour ,temperature will be 83.02 F and 14.0 % of sky occluded by clouds
# During 1561600800 hour ,temperature will be 81.97 F and 26.0 % of sky occluded by clouds
# During 1561604400 hour ,temperature will be 81.22 F and 34.0 % of sky occluded by clouds
# During 1561608000 hour ,temperature will be 80.76 F and 34.0 % of sky occluded by clouds
# During 1561611600 hour ,temperature will be 80.46 F and 32.0 % of sky occluded by clouds

# %% [markdown]
# # 8) For the next 24-ish hours in Miami, what percent of the time is the temperature above 85 degrees?
#
# If they give you 48 hours instead of 24, that's okay.
#
# - *Tip: You might want to read up on [looping patterns](http://jonathansoma.com/lede/foundations-2017/classes/data%20structures/looping-patterns/)*

# %%
count = 0
for data in miami_data_hourly['data']:
    if data['temperature'] > 85:
        count = count + 1
print("For " + str(round(count/48*100, 2))+ str("% of the time in the next 48 hours the temperature will be above 85 F"))
# Out:
# For 43.75% of the time in the next 48 hours the temperature will be above 85 F

# %% [markdown]
# ## 9) What was the temperature in Central Park on Christmas Day, 2012? How about 2007? 2005? How far back does the API allow you to go?
#
# - *Tip: You'll need to use UNIX time, which is the number of seconds since January 1, 1970. Google can help you convert a normal date!*
# - *Tip: You'll want to use Forecast.io's "time machine" API, [documentation here](https://darksky.net/dev/docs/time-machine)*

# %%
response=requests.get('https://api.darksky.net/forecast/37e68ae8fad94bcf37e87015f2f7a1b9/40.7829,%20-73.9654,%201356429600')
data2012 = response.json()
print( "Temperature in Central Park on Christmas Day, 2012 was", data2012['currently']['temperature'], "F")
# Out:
# Temperature in Central Park on Christmas Day, 2012 was 35.45 F

# %%
response=requests.get('https://api.darksky.net/forecast/37e68ae8fad94bcf37e87015f2f7a1b9/40.7829,%20-73.9654,1198558800')
data2007 = response.json()
print( "Temperature in Central Park on Christmas Day, 2007 was", data2007['currently']['temperature'], "F")
# Out:
# Temperature in Central Park on Christmas Day, 2007 was 38.57 F

# %%
response=requests.get('https://api.darksky.net/forecast/37e68ae8fad94bcf37e87015f2f7a1b9/40.7829,%20-73.9654,1135486800')
data2005 = response.json()
print( "Temperature in Central Park on Christmas Day, 2005 was", data2005['currently']['temperature'], "F")
# Out:
# Temperature in Central Park on Christmas Day, 2005 was 37.16 F
