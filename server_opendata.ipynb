# %% [markdown]
# <a href="https://colab.research.google.com/github/Suhailhassanbhat/Foundations-soma/blob/master/server_opendata.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
# !ls
# Out:
# sample_data

# %%
df = pd.read_csv("https://data.cityofnewyork.us/api/views/5rq2-4hqu/rows.csv?accessType=DOWNLOAD")

# %%
df.head()
# Out:
#         created_at  tree_id  block_id  ...  longitude          x_sp           y_sp
# 0       08/27/2015   180683    348711  ... -73.844215  1.027431e+06  202756.768749
# 1       09/03/2015   200540    315986  ... -73.818679  1.034456e+06  228644.837379
# 2       09/05/2015   204026    218365  ... -73.936608  1.001823e+06  200716.891267
# 3       09/05/2015   204337    217969  ... -73.934456  1.002420e+06  199244.253136
# 4       08/30/2015   189565    223043  ... -73.975979  9.909138e+05  182202.425999
# 5       08/30/2015   190422    106099  ... -73.984950  9.884187e+05  219825.522669
# 6       08/30/2015   190426    106099  ... -73.985338  9.883112e+05  219885.278455
# 7       09/07/2015   208649    103940  ... -73.987297  9.877691e+05  217157.856088
# 8       09/08/2015   209610    407443  ... -74.076255  9.630732e+05  156635.554233
# 9       08/31/2015   192755    207508  ... -73.969744  9.926537e+05  152903.630594
# ...

# %%
# %matplotlib inline
df.plot(kind='scatter', x='Latitude', y='longitude')

# %%
# !wget -O 311-data.csv https://nycopendata.socrata.com/api/views/erm2-nwe9/rows.csv?accessType=DOWNLOAD
# Out:
# --2019-06-22 14:43:24--  https://nycopendata.socrata.com/api/views/erm2-nwe9/rows.csv?accessType=DOWNLOAD
# Resolving nycopendata.socrata.com (nycopendata.socrata.com)... 52.206.68.26, 52.206.140.205, 52.206.140.199
# Connecting to nycopendata.socrata.com (nycopendata.socrata.com)|52.206.68.26|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/csv]
# Saving to: ‘311-data.csv’
#
# 311-data.csv            [               <=>  ]  11.09G  3.94MB/s    in 1h 44m
#
# Last-modified header invalid -- time-stamp ignored.
# 2019-06-22 16:28:10 (1.81 MB/s) - ‘311-data.csv’ saved [11912543817]

# %%
# !ls
# Out:
# 311-data.csv  sample_data

# %%
dtypes = {
    'Unique Key': 'str',
    'Created Date': 'str',
    'Closed Date': 'str',
    'Agency': 'category',
    'Agency Name': 'category',
    'Complaint Type': 'category',
    'Descriptor': 'category',
    'Incident Zip': 'category',
    'Incident Address': 'category',
    'Address Type': 'category',
    'Community Board': 'category',
    'Borough': 'category',
    'Latitude': 'str',
    'Longitude': 'str'
}
columns = dtypes.keys()

df = pd.read_csv("311-data.csv", usecols=columns, dtype=dtypes)
df.head()
# Out:
#   Unique Key            Created Date  ...            Latitude           Longitude
# 0   31066641  07/13/2015 05:19:38 PM  ...   40.60599980617937  -73.95267073833053
# 1   38749420  03/21/2018 11:22:39 PM  ...  40.526922582100454  -74.16522991230964
# 2   31066645  07/13/2015 01:25:17 PM  ...   40.82969569716946  -73.88133683617335
# 3   38758714  03/22/2018 03:44:25 PM  ...  40.549435282923625  -74.16351520214697
# 4   38759995  03/22/2018 01:48:22 PM  ...    40.5734842443546  -74.10592247446232
#
# [5 rows x 14 columns]

# %%
df.shape
# Out:
# (20979906, 14)

# %%
df.Agency.value_counts()
# Out:
# HPD      5803016
# NYPD     4802131
# DOT      2908540
# DSNY     1832204
# DEP      1645629
# DOB      1147427
# DPR       911867
# DOHMH     528513
# DOF       521548
# TLC       237516
# DCA       187758
# DHS       177660
# HRA       114262
# DFTA       93102
# 3-1-1      20594
# DOE        19020
# EDC         9920
# NYCEM       8815
# DOITT       6554
# DCAS        1845
# ACS         1206
# TAX          446
# DVS          123
# DCP           89
# DORIS         67
# TAT           22
# COIB          20
# CEO            5
# MOC            3
# OMB            2
# FDNY           2
# Name: Agency, dtype: int64
